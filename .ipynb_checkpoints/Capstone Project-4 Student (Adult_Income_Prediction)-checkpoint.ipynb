# %% [markdown]
# ![logo.png](attachment:logo.png)

# %% [markdown]
# # **Adult Income Prediction**

# %% [markdown]
# **Data Set Information:**
#
# This dataset was obtained from UCI Machine Learning Repository. The aim of this problem is to classify adults in two different groups based on their income where group 1 has an income less than USD 50k and group 2 has an income of more than or equal to USD 50k. The data available at hand comes from Census 1994.
#
#
# **Attribute Information:**
#
# Age: Describes the age of individuals. Continuous.
#
# Workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
#
# fnlwgt: Continuous.
#
# education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
#
# education-num: Number of years spent in education. Continuous.
#
# marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
#
# occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
#
# relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
#
# race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
#
# sex: Female, Male.
#
# capital-gain: Continuous.
#
# capital-loss: Continuous.
#
# hours-per-week: Continuous.
#
# native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
#
# salary: >50K,<=50K

# %% [markdown]
# # Exploratory Data Analysis and Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
import cufflinks as cf

# %matplotlib inline

from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import log_loss, recall_score, accuracy_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix
from sklearn.metrics import plot_roc_curve, plot_precision_recall_curve, roc_auc_score, auc
from sklearn.metrics import roc_curve, average_precision_score, precision_recall_curve
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.neighbors import KNeighborsClassifier
from scipy.stats import skew
from sklearn.tree import DecisionTreeClassifier
from yellowbrick.classifier import ClassPredictionError
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.metrics import make_scorer
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix


from sklearn.model_selection import cross_validate, cross_val_score
import warnings
warnings.filterwarnings('ignore')
plt.rcParams["figure.figsize"] = (14,8)
pd.set_option('display.max_columns', 500) 
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv("adult.csv")
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
#               occupation   relationship   race     sex  capital.gain  \
# 0                      ?  Not-in-family  White  Female             0
# 1        Exec-managerial  Not-in-family  White  Female             0
# 2                      ?      Unmarried  Black  Female             0
# 3      Machine-op-inspct      Unmarried  White  Female             0
# 4         Prof-specialty      Own-child  White  Female             0
# ...                  ...            ...    ...     ...           ...
# 32556    Protective-serv  Not-in-family  White    Male             0
# 32557       Tech-support           Wife  White  Female             0
# 32558  Machine-op-inspct        Husband  White    Male             0
# 32559       Adm-clerical      Unmarried  White  Female             0
# 32560       Adm-clerical      Own-child  White    Male             0
#
#        capital.loss  hours.per.week native.country income
# 0              4356              40  United-States  <=50K
# 1              4356              18  United-States  <=50K
# 2              4356              40  United-States  <=50K
# 3              3900              40  United-States  <=50K
# 4              3900              40  United-States  <=50K
# ...             ...             ...            ...    ...
# 32556             0              40  United-States  <=50K
# 32557             0              38  United-States  <=50K
# 32558             0              40  United-States   >50K
# 32559             0              40  United-States  <=50K
# 32560             0              20  United-States  <=50K
#
# [32561 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             32561.0      38.581647      13.640433     17.0      28.0
# fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# education.num   32561.0      10.080679       2.572720      1.0       9.0
# capital.gain    32561.0    1077.648844    7385.292085      0.0       0.0
# capital.loss    32561.0      87.303830     402.960219      0.0       0.0
# hours.per.week  32561.0      40.437456      12.347429      1.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178356.0  237051.0  1484705.0
# education.num       10.0      12.0       16.0
# capital.gain         0.0       0.0    99999.0
# capital.loss         0.0       0.0     4356.0
# hours.per.week      40.0      45.0       99.0

# %%
df.duplicated().value_counts()
# Out:
# False    32537
# True        24
# dtype: int64

# %%
df=df.drop_duplicates()

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
#Replacing '?' string with NaN values
df.replace(to_replace='?',value=np.nan,inplace=True)

# %%
df.isna().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     582
# income               0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.columns = df.columns.str.replace(".", "_")
df
# Out:
#        age workclass  fnlwgt     education  education_num      marital_status  \
# 1       82   Private  132870       HS-grad              9             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# 5       34   Private  216864       HS-grad              9            Divorced
# 6       38   Private  150601          10th              6           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
#               occupation   relationship   race     sex  capital_gain  \
# 1        Exec-managerial  Not-in-family  White  Female             0
# 3      Machine-op-inspct      Unmarried  White  Female             0
# 4         Prof-specialty      Own-child  White  Female             0
# 5          Other-service      Unmarried  White  Female             0
# 6           Adm-clerical      Unmarried  White    Male             0
# ...                  ...            ...    ...     ...           ...
# 32556    Protective-serv  Not-in-family  White    Male             0
# 32557       Tech-support           Wife  White  Female             0
# 32558  Machine-op-inspct        Husband  White    Male             0
# 32559       Adm-clerical      Unmarried  White  Female             0
# 32560       Adm-clerical      Own-child  White    Male             0
#
#        capital_loss  hours_per_week native_country income
# 1              4356              18  United-States  <=50K
# 3              3900              40  United-States  <=50K
# 4              3900              40  United-States  <=50K
# 5              3770              45  United-States  <=50K
# 6              3770              40  United-States  <=50K
# ...             ...             ...            ...    ...
# 32556             0              40  United-States  <=50K
# 32557             0              38  United-States  <=50K
# 32558             0              40  United-States   >50K
# 32559             0              40  United-States  <=50K
# 32560             0              20  United-States  <=50K
#
# [30139 rows x 15 columns]

# %% [markdown]
# ## Decreasing The Number of Categories In Features

# %% [markdown]
# ### EDUCATION

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
df.education.apply(mapping_education).value_counts()
# Out:
# medium_level_grade    18818
# high_level_grade       7585
# low_level_grade        3736
# Name: education, dtype: int64

# %%
df["education_summary"] = df.education.apply(mapping_education)

# %%
df = df.drop(['education', 'education_num'], axis=1)
df
# Out:
#        age workclass  fnlwgt      marital_status         occupation  \
# 1       82   Private  132870             Widowed    Exec-managerial
# 3       54   Private  140359            Divorced  Machine-op-inspct
# 4       41   Private  264663           Separated     Prof-specialty
# 5       34   Private  216864            Divorced      Other-service
# 6       38   Private  150601           Separated       Adm-clerical
# ...    ...       ...     ...                 ...                ...
# 32556   22   Private  310152       Never-married    Protective-serv
# 32557   27   Private  257302  Married-civ-spouse       Tech-support
# 32558   40   Private  154374  Married-civ-spouse  Machine-op-inspct
# 32559   58   Private  151910             Widowed       Adm-clerical
# 32560   22   Private  201490       Never-married       Adm-clerical
#
#         relationship   race     sex  capital_gain  capital_loss  \
# 1      Not-in-family  White  Female             0          4356
# 3          Unmarried  White  Female             0          3900
# 4          Own-child  White  Female             0          3900
# 5          Unmarried  White  Female             0          3770
# 6          Unmarried  White    Male             0          3770
# ...              ...    ...     ...           ...           ...
# 32556  Not-in-family  White    Male             0             0
# 32557           Wife  White  Female             0             0
# 32558        Husband  White    Male             0             0
# 32559      Unmarried  White  Female             0             0
# 32560      Own-child  White    Male             0             0
#
#        hours_per_week native_country income   education_summary
# 1                  18  United-States  <=50K  medium_level_grade
# 3                  40  United-States  <=50K     low_level_grade
# 4                  40  United-States  <=50K  medium_level_grade
# 5                  45  United-States  <=50K  medium_level_grade
# 6                  40  United-States  <=50K     low_level_grade
# ...               ...            ...    ...                 ...
# 32556              40  United-States  <=50K  medium_level_grade
# 32557              38  United-States  <=50K  medium_level_grade
# 32558              40  United-States   >50K  medium_level_grade
# 32559              40  United-States  <=50K  medium_level_grade
# 32560              20  United-States  <=50K  medium_level_grade
#
# [30139 rows x 14 columns]

# %% [markdown]
# ### MARITIAL STATUS

# %%
df['marital_status'].value_counts()
# Out:
# Married-civ-spouse       14059
# Never-married             9711
# Divorced                  4212
# Separated                  939
# Widowed                    827
# Married-spouse-absent      370
# Married-AF-spouse           21
# Name: marital_status, dtype: int64

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
df.marital_status.apply(mapping_marital_status).value_counts()
# Out:
# unmarried    15689
# married      14450
# Name: marital_status, dtype: int64

# %%
df["marital_status_summary"] = df.marital_status.apply(mapping_marital_status)

# %%
df = df.drop(['marital_status', 'relationship'], axis=1)
df
# Out:
#        age workclass  fnlwgt         occupation   race     sex  capital_gain  \
# 1       82   Private  132870    Exec-managerial  White  Female             0
# 3       54   Private  140359  Machine-op-inspct  White  Female             0
# 4       41   Private  264663     Prof-specialty  White  Female             0
# 5       34   Private  216864      Other-service  White  Female             0
# 6       38   Private  150601       Adm-clerical  White    Male             0
# ...    ...       ...     ...                ...    ...     ...           ...
# 32556   22   Private  310152    Protective-serv  White    Male             0
# 32557   27   Private  257302       Tech-support  White  Female             0
# 32558   40   Private  154374  Machine-op-inspct  White    Male             0
# 32559   58   Private  151910       Adm-clerical  White  Female             0
# 32560   22   Private  201490       Adm-clerical  White    Male             0
#
#        capital_loss  hours_per_week native_country income   education_summary  \
# 1              4356              18  United-States  <=50K  medium_level_grade
# 3              3900              40  United-States  <=50K     low_level_grade
# 4              3900              40  United-States  <=50K  medium_level_grade
# 5              3770              45  United-States  <=50K  medium_level_grade
# 6              3770              40  United-States  <=50K     low_level_grade
# ...             ...             ...            ...    ...                 ...
# 32556             0              40  United-States  <=50K  medium_level_grade
# 32557             0              38  United-States  <=50K  medium_level_grade
# 32558             0              40  United-States   >50K  medium_level_grade
# 32559             0              40  United-States  <=50K  medium_level_grade
# 32560             0              20  United-States  <=50K  medium_level_grade
#
#       marital_status_summary
# 1                  unmarried
# 3                  unmarried
# 4                  unmarried
# 5                  unmarried
# 6                  unmarried
# ...                      ...
# 32556              unmarried
# 32557                married
# 32558                married
# 32559              unmarried
# 32560              unmarried
#
# [30139 rows x 13 columns]

# %% [markdown]
# ### WORKCLASS

# %%
df['workclass'].value_counts()
# Out:
# Private             22264
# Self-emp-not-inc     2498
# Local-gov            2067
# State-gov            1279
# Self-emp-inc         1074
# Federal-gov           943
# Without-pay            14
# Name: workclass, dtype: int64

# %%
def mapping_workclass(x):
    if x in ["Local-gov", "State-gov", "Federal-gov"]:
        return "Government"
    elif x in ["Self-emp-not-inc", "Self-emp-inc"]:
        return "Self Employment"
    elif x in ["Private"]:
        return "Private"
    elif x in ["Without-pay"]:
        return "Without Pay"

# %%
df.workclass.apply(mapping_workclass).value_counts()
# Out:
# Private            22264
# Government          4289
# Self Employment     3572
# Without Pay           14
# Name: workclass, dtype: int64

# %%
df["workclass_summary"] = df.workclass.apply(mapping_workclass)

# %%
df = df.drop(['workclass'], axis=1)
df
# Out:
#        age  fnlwgt         occupation   race     sex  capital_gain  \
# 1       82  132870    Exec-managerial  White  Female             0
# 3       54  140359  Machine-op-inspct  White  Female             0
# 4       41  264663     Prof-specialty  White  Female             0
# 5       34  216864      Other-service  White  Female             0
# 6       38  150601       Adm-clerical  White    Male             0
# ...    ...     ...                ...    ...     ...           ...
# 32556   22  310152    Protective-serv  White    Male             0
# 32557   27  257302       Tech-support  White  Female             0
# 32558   40  154374  Machine-op-inspct  White    Male             0
# 32559   58  151910       Adm-clerical  White  Female             0
# 32560   22  201490       Adm-clerical  White    Male             0
#
#        capital_loss  hours_per_week native_country income   education_summary  \
# 1              4356              18  United-States  <=50K  medium_level_grade
# 3              3900              40  United-States  <=50K     low_level_grade
# 4              3900              40  United-States  <=50K  medium_level_grade
# 5              3770              45  United-States  <=50K  medium_level_grade
# 6              3770              40  United-States  <=50K     low_level_grade
# ...             ...             ...            ...    ...                 ...
# 32556             0              40  United-States  <=50K  medium_level_grade
# 32557             0              38  United-States  <=50K  medium_level_grade
# 32558             0              40  United-States   >50K  medium_level_grade
# 32559             0              40  United-States  <=50K  medium_level_grade
# 32560             0              20  United-States  <=50K  medium_level_grade
#
#       marital_status_summary workclass_summary
# 1                  unmarried           Private
# 3                  unmarried           Private
# 4                  unmarried           Private
# 5                  unmarried           Private
# 6                  unmarried           Private
# ...                      ...               ...
# 32556              unmarried           Private
# 32557                married           Private
# 32558                married           Private
# 32559              unmarried           Private
# 32560              unmarried           Private
#
# [30139 rows x 13 columns]

# %%
df = df.drop(['native_country', 'capital_gain', 'capital_loss'], axis=1)
df
# Out:
#        age  fnlwgt         occupation   race     sex  hours_per_week income  \
# 1       82  132870    Exec-managerial  White  Female              18  <=50K
# 3       54  140359  Machine-op-inspct  White  Female              40  <=50K
# 4       41  264663     Prof-specialty  White  Female              40  <=50K
# 5       34  216864      Other-service  White  Female              45  <=50K
# 6       38  150601       Adm-clerical  White    Male              40  <=50K
# ...    ...     ...                ...    ...     ...             ...    ...
# 32556   22  310152    Protective-serv  White    Male              40  <=50K
# 32557   27  257302       Tech-support  White  Female              38  <=50K
# 32558   40  154374  Machine-op-inspct  White    Male              40   >50K
# 32559   58  151910       Adm-clerical  White  Female              40  <=50K
# 32560   22  201490       Adm-clerical  White    Male              20  <=50K
#
#         education_summary marital_status_summary workclass_summary
# 1      medium_level_grade              unmarried           Private
# 3         low_level_grade              unmarried           Private
# 4      medium_level_grade              unmarried           Private
# 5      medium_level_grade              unmarried           Private
# 6         low_level_grade              unmarried           Private
# ...                   ...                    ...               ...
# 32556  medium_level_grade              unmarried           Private
# 32557  medium_level_grade                married           Private
# 32558  medium_level_grade                married           Private
# 32559  medium_level_grade              unmarried           Private
# 32560  medium_level_grade              unmarried           Private
#
# [30139 rows x 10 columns]

# %% [markdown]
# In native country close to 91% of observations belong to one category (i.e. United States).
#
#
# Whereas in capital-gain and capital-loss, ~92% and ~95% of values are zeroes respectively which will not contribute in modelling
#
#
# Hence, we drop these 3 variables (native-country, capital-gain, capital-loss) from the feature matrix

# %%
df = df.drop(['fnlwgt', 'race', 'sex', 'marital_status_summary' ], axis=1)
df
# Out:
#        age         occupation  hours_per_week income   education_summary  \
# 1       82    Exec-managerial              18  <=50K  medium_level_grade
# 3       54  Machine-op-inspct              40  <=50K     low_level_grade
# 4       41     Prof-specialty              40  <=50K  medium_level_grade
# 5       34      Other-service              45  <=50K  medium_level_grade
# 6       38       Adm-clerical              40  <=50K     low_level_grade
# ...    ...                ...             ...    ...                 ...
# 32556   22    Protective-serv              40  <=50K  medium_level_grade
# 32557   27       Tech-support              38  <=50K  medium_level_grade
# 32558   40  Machine-op-inspct              40   >50K  medium_level_grade
# 32559   58       Adm-clerical              40  <=50K  medium_level_grade
# 32560   22       Adm-clerical              20  <=50K  medium_level_grade
#
#       workclass_summary
# 1               Private
# 3               Private
# 4               Private
# 5               Private
# 6               Private
# ...                 ...
# 32556           Private
# 32557           Private
# 32558           Private
# 32559           Private
# 32560           Private
#
# [30139 rows x 6 columns]

# %% [markdown]
# ## ADJUSTING THE TARGET

# %%
df['income'].replace(to_replace='<=50K',value=0,inplace=True)
df['income'].replace(to_replace='>50K',value=1,inplace=True)
df
# Out:
#        age         occupation  hours_per_week  income   education_summary  \
# 1       82    Exec-managerial              18       0  medium_level_grade
# 3       54  Machine-op-inspct              40       0     low_level_grade
# 4       41     Prof-specialty              40       0  medium_level_grade
# 5       34      Other-service              45       0  medium_level_grade
# 6       38       Adm-clerical              40       0     low_level_grade
# ...    ...                ...             ...     ...                 ...
# 32556   22    Protective-serv              40       0  medium_level_grade
# 32557   27       Tech-support              38       0  medium_level_grade
# 32558   40  Machine-op-inspct              40       1  medium_level_grade
# 32559   58       Adm-clerical              40       0  medium_level_grade
# 32560   22       Adm-clerical              20       0  medium_level_grade
#
#       workclass_summary
# 1               Private
# 3               Private
# 4               Private
# 5               Private
# 6               Private
# ...                 ...
# 32556           Private
# 32557           Private
# 32558           Private
# 32559           Private
# 32560           Private
#
# [30139 rows x 6 columns]

# %%
new_column_order = ['age', 'occupation', 'hours_per_week', 'education_summary', 'workclass_summary', 'income']
df = df.reindex(columns=new_column_order)
df
# Out:
#        age         occupation  hours_per_week   education_summary  \
# 1       82    Exec-managerial              18  medium_level_grade
# 3       54  Machine-op-inspct              40     low_level_grade
# 4       41     Prof-specialty              40  medium_level_grade
# 5       34      Other-service              45  medium_level_grade
# 6       38       Adm-clerical              40     low_level_grade
# ...    ...                ...             ...                 ...
# 32556   22    Protective-serv              40  medium_level_grade
# 32557   27       Tech-support              38  medium_level_grade
# 32558   40  Machine-op-inspct              40  medium_level_grade
# 32559   58       Adm-clerical              40  medium_level_grade
# 32560   22       Adm-clerical              20  medium_level_grade
#
#       workclass_summary  income
# 1               Private       0
# 3               Private       0
# 4               Private       0
# 5               Private       0
# 6               Private       0
# ...                 ...     ...
# 32556           Private       0
# 32557           Private       0
# 32558           Private       1
# 32559           Private       0
# 32560           Private       0
#
# [30139 rows x 6 columns]

# %% [markdown]
# ## VISUALIZATION

# %%
plt.figure(figsize=(14,8))
correlation = df.corr()
matrix = np.triu(correlation)
sns.heatmap(correlation,cmap='coolwarm',square=True,linecolor='black',linewidths=1,
            mask=matrix,annot=True)
plt.show()

# %%
cols_df = pd.DataFrame(df.dtypes)
num_cols = list(cols_df[cols_df[0]=='int64'].index)
cat_cols = list(cols_df[cols_df[0]=='object'].index)[:-1] #excluding target column of income 
print('Numeric variables includes:','\n',num_cols)
print('\n')
print('Categorical variables includes','\n',cat_cols)
# Out:
# Numeric variables includes:
#  ['age', 'hours_per_week', 'income']
#
#
# Categorical variables includes
#  ['occupation', 'education_summary']

# %%
for i in cat_cols:
    ct = pd.crosstab(df[i],df['income'],margins=True, margins_name="Total")
    ct.drop(labels='Total',axis=0,inplace=True) #Removing subtotal row 
    ct.sort_values(by='Total',ascending=False,inplace=True) #Sorting based on total column
    #Selecting only top 6 categories for plotting
    ct.iloc[:6,:].plot(kind='bar',colormap='viridis',edgecolor='black')  
    plt.xlabel(' ')
    plt.title(str(i).capitalize())
    plt.legend(loc=1)
    plt.show()

# %%
for i in num_cols:
    df[df['income']==0][i].hist(color='mediumblue')
    df[df['income']==1][i].hist(color='firebrick')
    plt.title(i)
    plt.show()

# %% [markdown]
# ## DEFINING X AND Y

# %%
df
# Out:
#        age         occupation  hours_per_week   education_summary  \
# 1       82    Exec-managerial              18  medium_level_grade
# 3       54  Machine-op-inspct              40     low_level_grade
# 4       41     Prof-specialty              40  medium_level_grade
# 5       34      Other-service              45  medium_level_grade
# 6       38       Adm-clerical              40     low_level_grade
# ...    ...                ...             ...                 ...
# 32556   22    Protective-serv              40  medium_level_grade
# 32557   27       Tech-support              38  medium_level_grade
# 32558   40  Machine-op-inspct              40  medium_level_grade
# 32559   58       Adm-clerical              40  medium_level_grade
# 32560   22       Adm-clerical              20  medium_level_grade
#
#       workclass_summary  income
# 1               Private       0
# 3               Private       0
# 4               Private       0
# 5               Private       0
# 6               Private       0
# ...                 ...     ...
# 32556           Private       0
# 32557           Private       0
# 32558           Private       1
# 32559           Private       0
# 32560           Private       0
#
# [30139 rows x 6 columns]

# %%
X = df.drop(['income'], axis = 1)
y = df['income']

# %%
X = pd.get_dummies(data=X,drop_first=True)
X
# Out:
#        age  hours_per_week  occupation_Armed-Forces  occupation_Craft-repair  \
# 1       82              18                        0                        0
# 3       54              40                        0                        0
# 4       41              40                        0                        0
# 5       34              45                        0                        0
# 6       38              40                        0                        0
# ...    ...             ...                      ...                      ...
# 32556   22              40                        0                        0
# 32557   27              38                        0                        0
# 32558   40              40                        0                        0
# 32559   58              40                        0                        0
# 32560   22              20                        0                        0
#
#        occupation_Exec-managerial  occupation_Farming-fishing  \
# 1                               1                           0
# 3                               0                           0
# 4                               0                           0
# 5                               0                           0
# 6                               0                           0
# ...                           ...                         ...
# 32556                           0                           0
# 32557                           0                           0
# 32558                           0                           0
# 32559                           0                           0
# 32560                           0                           0
#
#        occupation_Handlers-cleaners  occupation_Machine-op-inspct  \
# 1                                 0                             0
# 3                                 0                             1
# 4                                 0                             0
# 5                                 0                             0
# 6                                 0                             0
# ...                             ...                           ...
# 32556                             0                             0
# 32557                             0                             0
# 32558                             0                             1
# 32559                             0                             0
# 32560                             0                             0
#
#        occupation_Other-service  occupation_Priv-house-serv  \
# 1                             0                           0
# 3                             0                           0
# 4                             0                           0
# 5                             1                           0
# 6                             0                           0
# ...                         ...                         ...
# 32556                         0                           0
# 32557                         0                           0
# 32558                         0                           0
# 32559                         0                           0
# 32560                         0                           0
#
#        occupation_Prof-specialty  occupation_Protective-serv  \
# 1                              0                           0
# 3                              0                           0
# 4                              1                           0
# 5                              0                           0
# 6                              0                           0
# ...                          ...                         ...
# 32556                          0                           1
# 32557                          0                           0
# 32558                          0                           0
# 32559                          0                           0
# 32560                          0                           0
#
#        occupation_Sales  occupation_Tech-support  occupation_Transport-moving  \
# 1                     0                        0                            0
# 3                     0                        0                            0
# 4                     0                        0                            0
# 5                     0                        0                            0
# 6                     0                        0                            0
# ...                 ...                      ...                          ...
# 32556                 0                        0                            0
# 32557                 0                        1                            0
# 32558                 0                        0                            0
# 32559                 0                        0                            0
# 32560                 0                        0                            0
#
#        education_summary_low_level_grade  \
# 1                                      0
# 3                                      1
# 4                                      0
# 5                                      0
# 6                                      1
# ...                                  ...
# 32556                                  0
# 32557                                  0
# 32558                                  0
# 32559                                  0
# 32560                                  0
#
#        education_summary_medium_level_grade  workclass_summary_Private  \
# 1                                         1                          1
# 3                                         0                          1
# 4                                         1                          1
# 5                                         1                          1
# 6                                         0                          1
# ...                                     ...                        ...
# 32556                                     1                          1
# 32557                                     1                          1
# 32558                                     1                          1
# 32559                                     1                          1
# 32560                                     1                          1
#
#        workclass_summary_Self Employment  workclass_summary_Without Pay
# 1                                      0                              0
# 3                                      0                              0
# 4                                      0                              0
# 5                                      0                              0
# 6                                      0                              0
# ...                                  ...                            ...
# 32556                                  0                              0
# 32557                                  0                              0
# 32558                                  0                              0
# 32559                                  0                              0
# 32560                                  0                              0
#
# [30139 rows x 20 columns]

# %%
y
# Out:
# 1        0
# 3        0
# 4        0
# 5        0
# 6        0
#         ..
# 32556    0
# 32557    0
# 32558    1
# 32559    0
# 32560    0
# Name: income, Length: 30139, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# # Logistic Regression

# %%
# Define the pipeline
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('logreg', LogisticRegression())
])

# %%
# Define the parameter grid to search over
param_grid = {
    'logreg__C': [0.001, 0.01, 0.1, 1, 10, 100],
    'logreg__penalty': ['l1', 'l2']
}

# %%
# Perform grid search with cross-validation
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('logreg', LogisticRegression())]),
#              param_grid={'logreg__C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'logreg__penalty': ['l1', 'l2']})

# %%
best_params = grid.best_params_

# %%
log_model = LogisticRegression(C=best_params['logreg__C'], penalty=best_params['logreg__penalty'])

# %%
log_model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1)

# %%
train_score = log_model.score(X_train, y_train)
print("Training set score: {:.3f}".format(train_score))
# Out:
# Training set score: 0.787

# %%
test_score = log_model.score(X_test, y_test)
print("Test set score: {:.3f}".format(test_score))
# Out:
# Test set score: 0.800

# %% [markdown]
# # K-Nearest Neighbors (KNN) Classification

# %%
# Define the pipeline
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier())
])

# %%
# Define the parameter grid to search over
param_grid = {
    'knn__n_neighbors': [3, 5, 7],
    'knn__weights': ['uniform', 'distance'],
}

# %%
# Perform grid search with cross-validation
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('knn', KNeighborsClassifier())]),
#              param_grid={'knn__n_neighbors': [3, 5, 7],
#                          'knn__weights': ['uniform', 'distance']})

# %%
best_params = grid.best_params_

# %%
knn_model = KNeighborsClassifier(n_neighbors=best_params['knn__n_neighbors'], weights=best_params['knn__weights'])

# %%
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
# Calculate the test set score
test_score = knn_model.score(X_test, y_test)
print("Test set score: {:.3f}".format(test_score))
# Out:
# Test set score: 0.771

# %%
train_score = knn_model.score(X_train, y_train)
print("Training set score: {:.3f}".format(train_score))
# Out:
# Training set score: 0.814

# %% [markdown]
# # Decision Tree Classification

# %%
# Define the pipeline
pipe = Pipeline([
    ('decision_tree', DecisionTreeClassifier())
])

# %%
# Define the parameter grid to search over
param_grid = {
    'decision_tree__max_depth': [None, 2, 4, 6, 8, 10],
    'decision_tree__min_samples_split': [20, 25, 30, 35],
    'decision_tree__min_samples_leaf': [5, 6, 7],
}

# %%
# Perform grid search with cross-validation
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('decision_tree',
#                                         DecisionTreeClassifier())]),
#              param_grid={'decision_tree__max_depth': [None, 2, 4, 6, 8, 10],
#                          'decision_tree__min_samples_leaf': [5, 6, 7],
#                          'decision_tree__min_samples_split': [20, 25, 30, 35]})

# %%
# Get the best hyperparameters
best_params = grid.best_params_

# %%
best_params
# Out:
# {'decision_tree__max_depth': 8,
#  'decision_tree__min_samples_leaf': 6,
#  'decision_tree__min_samples_split': 35}

# %%
best_params
# Out:
# {'decision_tree__max_depth': 8,
#  'decision_tree__min_samples_leaf': 6,
#  'decision_tree__min_samples_split': 35}

# %%
# Create a new Decision Tree model with the best hyperparameters
tree_model = DecisionTreeClassifier(max_depth=best_params['decision_tree__max_depth'],
                               min_samples_split=best_params['decision_tree__min_samples_split'],
                               min_samples_leaf=best_params['decision_tree__min_samples_leaf'])

# %%
# Fit the model on the entire training set
tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=8, min_samples_leaf=6, min_samples_split=35)

# %%
# Calculate the test set score
test_score = tree_model.score(X_test, y_test)
print("Test set score: {:.3f}".format(test_score))
# Out:
# Test set score: 0.803

# %%
train_score = tree_model.score(X_train, y_train)
print("Training set score: {:.3f}".format(train_score))
# Out:
# Training set score: 0.798

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %% [markdown]
# # CONCLUSION

# %%
eval_metric(tree_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[4245  282]
#  [ 904  597]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.94      0.88      4527
#            1       0.68      0.40      0.50      1501
#
#     accuracy                           0.80      6028
#    macro avg       0.75      0.67      0.69      6028
# weighted avg       0.79      0.80      0.78      6028
#
#
# Train_Set
# [[16946  1160]
#  [ 3711  2294]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.94      0.87     18106
#            1       0.66      0.38      0.49      6005
#
#     accuracy                           0.80     24111
#    macro avg       0.74      0.66      0.68     24111
# weighted avg       0.78      0.80      0.78     24111

# %%
eval_metric(knn_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[3980  547]
#  [ 831  670]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85      4527
#            1       0.55      0.45      0.49      1501
#
#     accuracy                           0.77      6028
#    macro avg       0.69      0.66      0.67      6028
# weighted avg       0.76      0.77      0.76      6028
#
#
# Train_Set
# [[16507  1599]
#  [ 2887  3118]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88     18106
#            1       0.66      0.52      0.58      6005
#
#     accuracy                           0.81     24111
#    macro avg       0.76      0.72      0.73     24111
# weighted avg       0.80      0.81      0.81     24111

# %%
eval_metric(log_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[4217  310]
#  [ 895  606]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87      4527
#            1       0.66      0.40      0.50      1501
#
#     accuracy                           0.80      6028
#    macro avg       0.74      0.67      0.69      6028
# weighted avg       0.78      0.80      0.78      6028
#
#
# Train_Set
# [[16761  1345]
#  [ 3782  2223]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87     18106
#            1       0.62      0.37      0.46      6005
#
#     accuracy                           0.79     24111
#    macro avg       0.72      0.65      0.67     24111
# weighted avg       0.77      0.79      0.77     24111

# %% [markdown]
# ***LOOKS LIKE WE HAVE PRETTY MUCH SIMILAR RESULTS FOR ALL 3 MODELS***

# %% [markdown]
# # THE END
